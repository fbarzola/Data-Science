# %%
import time
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
   
# Lee el archivo CSV en un DataFrame
df_usdt = pd.read_csv('datos_usdt.csv')


df_btcusdt = df_usdt[df_usdt['Criptomoneda'] == 'BTCUSDT']
df_ethusdt = df_usdt[df_usdt['Criptomoneda'] == 'ETHUSDT']
df_trxusdt = df_usdt[df_usdt['Criptomoneda'] == 'TRXUSDT']

# Muestra los primeros 100 registros de cada DataFrame por separado
df_btcusdt.head(200)
# Out:
#     Criptomoneda    Precio       Fecha  Horas  Minutos  Segundos
# 0        BTCUSDT  49862.05  2024-02-12     17       14        40
# 3        BTCUSDT  49862.04  2024-02-12     17       14        57
# 6        BTCUSDT  49859.98  2024-02-12     17       15        29
# 9        BTCUSDT  49867.84  2024-02-12     17       15        59
# 12       BTCUSDT  49899.98  2024-02-12     17       16        29
# 15       BTCUSDT  49898.25  2024-02-12     17       17         0
# 18       BTCUSDT  49897.99  2024-02-12     17       17        30
# 21       BTCUSDT  49902.88  2024-02-12     17       18         1
# 24       BTCUSDT  49908.01  2024-02-12     17       18        31
# 27       BTCUSDT  49840.01  2024-02-12     17       19         1
# 30       BTCUSDT  49849.07  2024-02-12     17       19        32
# 33       BTCUSDT  49876.84  2024-02-12     17       20         2
# 36       BTCUSDT  49875.00  2024-02-12     17       20        32
# 39       BTCUSDT  49872.81  2024-02-12     17       21         3
# 42       BTCUSDT  49861.09  2024-02-12     17       21        34
# 45       BTCUSDT  49876.00  2024-02-12     17       22         4
# 48       BTCUSDT  49852.94  2024-02-12     17       22        35
# 51       BTCUSDT  49852.80  2024-02-12     17       23         5
# 54       BTCUSDT  49875.53  2024-02-12     17       23        35
# 57       BTCUSDT  49875.51  2024-02-12     17       24         6
# 60       BTCUSDT  49870.00  2024-02-12     17       24        37
# 63       BTCUSDT  49856.74  2024-02-12     17       25         7
# 66       BTCUSDT  49857.42  2024-02-12     17       25        38
# 69       BTCUSDT  49897.97  2024-02-12     17       26         8
# 72       BTCUSDT  49902.87  2024-02-12     17       26        38
# 75       BTCUSDT  49905.29  2024-02-12     17       27         9
# 78       BTCUSDT  49914.00  2024-02-12     17       27        39
# 81       BTCUSDT  49907.91  2024-02-12     17       28        10
# 84       BTCUSDT  49933.70  2024-02-12     17       28        42
# 87       BTCUSDT  49949.88  2024-02-12     17       29        12
# 90       BTCUSDT  49896.34  2024-02-12     17       29        43
# 93       BTCUSDT  49912.64  2024-02-12     17       30        13
# 96       BTCUSDT  49921.09  2024-02-12     17       30        48
# 99       BTCUSDT  49939.69  2024-02-12     17       31        19
# 102      BTCUSDT  49940.02  2024-02-12     17       31        50
# 105      BTCUSDT  49942.05  2024-02-12     17       32        20
# 108      BTCUSDT  49944.29  2024-02-12     17       32        51
# 111      BTCUSDT  49921.11  2024-02-12     17       33        22
# 114      BTCUSDT  49929.38  2024-02-12     17       33        52
# 117      BTCUSDT  49893.99  2024-02-12     17       34        22
# 120      BTCUSDT  49856.75  2024-02-12     17       34        53
# 79       ETHUSDT  2624.20  2024-02-12     17       27        39
# 82       ETHUSDT  2623.21  2024-02-12     17       28        10
# 85       ETHUSDT  2622.66  2024-02-12     17       28        42
# 88       ETHUSDT  2623.01  2024-02-12     17       29        12
# 91       ETHUSDT  2622.43  2024-02-12     17       29        43
# 94       ETHUSDT  2622.86  2024-02-12     17       30        13
# 97       ETHUSDT  2623.39  2024-02-12     17       30        48
# 100      ETHUSDT  2624.20  2024-02-12     17       31        19
# 103      ETHUSDT  2624.07  2024-02-12     17       31        50
# 106      ETHUSDT  2624.61  2024-02-12     17       32        20
# 109      ETHUSDT  2624.26  2024-02-12     17       32        51
# 112      ETHUSDT  2623.32  2024-02-12     17       33        22
# 115      ETHUSDT  2624.06  2024-02-12     17       33        52
# 118      ETHUSDT  2622.65  2024-02-12     17       34        22
# 121      ETHUSDT  2622.65  2024-02-12     17       34        53
# 124      ETHUSDT  2622.50  2024-02-12     17       35        23
# 127      ETHUSDT  2622.40  2024-02-12     17       35        53
# 130      ETHUSDT  2623.06  2024-02-12     17       36        24
# 133      ETHUSDT  2624.24  2024-02-12     17       36        55
# 136      ETHUSDT  2625.25  2024-02-12     17       37        25
# 139      ETHUSDT  2624.01  2024-02-12     17       37        57
# 142      ETHUSDT  2621.84  2024-02-12     17       38        27
# 145      ETHUSDT  2622.38  2024-02-12     17       38        57
# 148      ETHUSDT  2622.82  2024-02-12     17       39        28
# 151      ETHUSDT  2622.06  2024-02-12     17       39        58
# 154      ETHUSDT  2621.65  2024-02-12     17       40        28
# 157      ETHUSDT  2623.78  2024-02-12     17       40        59
# 160      ETHUSDT  2634.94  2024-02-12     18       49        40
# 163      ETHUSDT  2634.08  2024-02-12     18       50        11
# 166      ETHUSDT  2635.44  2024-02-12     18       50        41

# %%
# Configurar el gráfico para BTCUSDT
plt.figure(figsize=(10, 6))
plt.plot(df_btcusdt['Minutos'], df_btcusdt['Precio'], label='BTCUSDT', color='blue')

# Configurar el formato del eje x para mostrar cada 5 minutos
plt.gca().xaxis.set_major_formatter(DateFormatter('%H:%M'))

# Mostrar solo cada 5 minutos en el eje x
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(5))

plt.title('Precio de BTCUSDT')
plt.xlabel('Minutos')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Configurar el gráfico para ETHUSDT
plt.figure(figsize=(10, 6))
plt.plot(df_ethusdt['Minutos'], df_ethusdt['Precio'], label='ETHUSDT', color='green')

# Configurar el formato del eje x para mostrar cada 5 minutos
plt.gca().xaxis.set_major_formatter(DateFormatter('%H:%M'))

# Mostrar solo cada 5 minutos en el eje x
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(5))

plt.title('Precio de ETHUSDT')
plt.xlabel('Minutos')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Graficar los precios de TRXUSDT
plt.plot(df_trxusdt['Minutos'], df_trxusdt['Precio'], label='TRXUSDT')
plt.title('Precio de TRXUSDT')
plt.xlabel('Minutos')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py:1506, in Axis.convert_units(self, x)
#    1505 try:
# -> 1506     ret = self.converter.convert(x, self.units, self)
#    1507 except Exception as e:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\category.py:68, in StrCategoryConverter.convert(value, unit, axis)
#      67 # force an update so it also does type checking
# ---> 68 unit.update(values)
#      69 return np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\category.py:227, in UnitData.update(self, data)
#     225 for val in OrderedDict.fromkeys(data):
#     226     # OrderedDict just iterates over unique values in data.
# --> 227     _api.check_isinstance((str, bytes), value=val)
#     228     if convertible:
#     229         # this will only be called so long as convertible is True.
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\_api\__init__.py:93, in check_isinstance(_types, **kwargs)
#      92     names.append("None")
# ---> 93 raise TypeError(
#      94     "{!r} must be an instance of {}, not a {}".format(
#      95         k,
#      96         ", ".join(names[:-1]) + " or " + names[-1]
#      97         if len(names) > 1 else names[0],
#      98         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a pandas._libs.tslibs.timestamps.Timestamp
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Input In [6], in <cell line: 8>()
#       5 plt.plot(df_trxusdt['Fecha'], df_trxusdt['Precio'], label='TRXUSDT', color='red')
#       7 # Configurar los límites del eje x para mostrar cada 10 minutos
# ----> 8 plt.xlim(pd.to_datetime(df_trxusdt['Fecha']).iloc[0], pd.to_datetime(df_trxusdt['Fecha']).iloc[-1])
#       9 plt.xticks(pd.date_range(start=pd.to_datetime(df_trxusdt['Fecha']).iloc[0],
#      10                          end=pd.to_datetime(df_trxusdt['Fecha']).iloc[-1], freq='10T'), rotation=45)
#      12 plt.title('Precio de TRXUSDT')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:1699, in xlim(*args, **kwargs)
#    1697 if not args and not kwargs:
#    1698     return ax.get_xlim()
# -> 1699 ret = ax.set_xlim(*args, **kwargs)
#    1700 return ret
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:3688, in _AxesBase.set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3685     right = xmax
#    3687 self._process_unit_info([("x", (left, right))], convert=False)
# -> 3688 left = self._validate_converted_limits(left, self.convert_xunits)
#    3689 right = self._validate_converted_limits(right, self.convert_xunits)
#    3691 if left is None or right is None:
#    3692     # Axes init calls set_xlim(0, 1) before get_xlim() can be called,
#    3693     # so only grab the limits if we really need them.
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:3602, in _AxesBase._validate_converted_limits(self, limit, convert)
#    3592 """
#    3593 Raise ValueError if converted limits are non-finite.
#    3594
#    (...)
#    3599 The limit value after call to convert(), or None if limit is None.
#    3600 """
#    3601 if limit is not None:
# -> 3602     converted_limit = convert(limit)
#    3603     if (isinstance(converted_limit, Real)
#    3604             and not np.isfinite(converted_limit)):
#    3605         raise ValueError("Axis limits cannot be NaN or Inf")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py:252, in Artist.convert_xunits(self, x)
#     250 if ax is None or ax.xaxis is None:
#     251     return x
# --> 252 return ax.xaxis.convert_units(x)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py:1508, in Axis.convert_units(self, x)
#    1506     ret = self.converter.convert(x, self.units, self)
#    1507 except Exception as e:
# -> 1508     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1509                                  f'units: {x!r}') from e
#    1510 return ret
#
# ConversionError: Failed to convert value(s) to axis units: Timestamp('2024-02-12 00:00:00')
