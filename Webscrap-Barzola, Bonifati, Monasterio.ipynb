# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from lxml import etree
from datetime import date
from datetime import datetime
import seaborn as sns

# %% [markdown]
# # ENTREGA WEB SACRAP

# %% [markdown]
# El objetivo de esta entrega es realizar webscraping de una busqueda en mercadolibre sobre un determinado modelo de auto para hacer una clasificacion segun los precios, modelo, año, km. Luego de este analisis podremos determinar cual es el precio acorde para publicar un auto de similares caracteristicas.

# %%
url = requests.get('https://listado.mercadolibre.com.ar/peugeot-208-feline-2018')
url.status_code
# Out:
# 200

# %%
#check (No hace falta hacerlo)
url.content
# Out:
# b'\n<!DOCTYPE html>\n<html lang="es-AR">\n<head><link rel="preconnect" href="https://www.google-analytics.com"/><link rel="preconnect" href="https://www.google.com"/><link rel="preconnect" href="https://data.mercadolibre.com"/><link rel="preconnect" href="https://http2.mlstatic.com"/><link rel="preconnect" href="https://stats.g.doubleclick.net"/><link rel="preconnect" href="https://analytics.mercadolibre.com.ar"/><link rel="preconnect" href="https://analytics.mercadolibre.com"/><link rel="preconnect" href="https://www.google.com.ar"/><script type=\'text/javascript\' nonce="bEWGLX9VeHiUvBnkzoYRfA==">window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"NRBR-766f4fb616d3a2368ce","applicationID":"1729522169","agentToken":null,"applicationTime":494.712558,"transactionName":"bgQDMEcFXkJZBkYNWldOJBxFFlVCSw9BS3J8NU5LHw==","queueTime":0,"ttGuid":"cbc3ce23c08277dc"}; (window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:
# ...

# %%
soup = BeautifulSoup(url.content, 'html.parser')

# %%
titulos = soup.find_all('h2', attrs={"class":'ui-search-item__title ui-search-item__group__element shops__items-group-details shops__item-title'})

# %%
titulos[0].text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 titulos[0].text
#
# IndexError: list index out of range

# %%
#(No hace falta hacerlo)
for i in titulos:
    
    print(i.text)

# %%
titulos = [i.text for i in titulos]

# %%
titulos

# %%
len(titulos)

# %%
urls = soup.find_all('a', class_="nav-header nav-header-plus ui-navigation-v2")

# %%
urls[0].get('href')

# %%
urls = [i.get('href') for i in urls]
urls

# %%
print(len(titulos))
len(urls)

# %%
df = pd.DataFrame({'titulos':titulos, 'url':urls})
df['fecha_obs'] = date.today()
df

# %%
precio = soup.find_all('div', class_="ui-search-item__group__element ui-search-price__part-without-link")

precio

# %%
precio = [p.text for p in precio]

# %%
#precio = [p[12:] for p in precio]
precio

# %%
len(precio)

# %%
df = pd.DataFrame({'titulos':titulos, 'url':urls, 'precio':precio })
df['fecha_obs'] = date.today()
df
